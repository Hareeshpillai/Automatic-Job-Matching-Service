# %%
import requests
from bs4 import BeautifulSoup
import pandas

query = "Dr.%20Usharani%20Hareesh%20Govindarajan"
url = 'https://scholar.google.com/scholar?q=' + query + '&ie=UTF-8&oe=UTF-8&hl=en&btnG=Search'

content = requests.get(url).text
page = BeautifulSoup(content, 'lxml')
results = []
for entry in page.find_all("h3", attrs={"class": "gs_rt"}):
    results.append({"TITLE": entry.a.text, "LINK": entry.a['href']})

tables = pandas.DataFrame(results)
tables
# Out:
#                                                  LINK  \
# 0   /citations?view_op=search_authors&mauthors=Dr....
# 1   https://ieeexplore.ieee.org/abstract/document/...
# 2   https://www.sciencedirect.com/science/article/...
# 3   https://www.ijosi.org/index.php/IJOSI/article/...
# 4   https://www.sciencedirect.com/science/article/...
# 5   http://repository.unpar.ac.id/handle/123456789...
# 6   http://repository.unpar.ac.id/handle/123456789...
# 7   https://pdfs.semanticscholar.org/8bb7/83f33fda...
# 8   http://www.ep.liu.se/ecp/article.asp?issue=153...
# 9    https://dergipark.org.tr/hiad/issue/44355/548482
# 10  https://books.google.com/books?hl=en&lr=&id=x_...
#
#                                                 TITLE
# 0   User profiles for Dr. Usharani Hareesh Govinda...
# 1   A review of technology standards and patent po...
# 2   Construction and validation of an ontology-bas...
# 3   Review of Systematic Software Innovation Using...
# 4   A review of essential standards and patent lan...
# 5   A Metaheuristic approach for the vehicle routi...
# 6   Understanding the impact of information sharin...
# 7   Brain–computer interface devices for patients ...
# 8   Oil and Gas digital twins after twenty years. ...
# 9   Endüstri 4.0 Ve Türkiye Kamu Sektöründe Endüst...
# 10  Information and Communication Technologies: In...
